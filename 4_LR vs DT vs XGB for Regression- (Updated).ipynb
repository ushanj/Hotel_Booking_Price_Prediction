# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style
style.use('seaborn')
import numpy as np
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("Travel_scrape.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051 entries, 0 to 8050
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hotel          8051 non-null   object
#  1   Room Type      8051 non-null   object
#  2   Rate           8051 non-null   object
#  3   Check-in Date  8051 non-null   object
#  4   Search Date    8051 non-null   object
#  5   Search Time    8051 non-null   object
#  6   Unnamed: 6     0 non-null      float64
# dtypes: float64(1), object(6)
# memory usage: 440.4+ KB

# %%
df.isnull().sum()
# Out:
# Hotel               0
# Room Type           0
# Rate                0
# Check-in Date       0
# Search Date         0
# Search Time         0
# Unnamed: 6       8051
# dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='Hotel',data=df)
plt.title('Hotel Wise Booking Count')
plt.show()

# %%
sns.countplot(x='Room Type' , data= df)
plt.title('Room type Wise Booking Count')
plt.show()

# %%
df = df.drop('Unnamed: 6', axis=1)
df.head()
# Out:
#                                                Hotel            Room Type  \
# 0  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 1  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 2  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 3  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 4  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
#
#      Rate Check-in Date Search Date Search Time
# 0  US$254    2022-08-03  2022-08-03     0:00:00
# 1  US$254    2022-08-03  2022-08-03     1:00:00
# 2  US$254    2022-08-03  2022-08-03     2:00:00
# 3  US$254    2022-08-03  2022-08-03     3:00:00
# 4  US$254    2022-08-03  2022-08-03     4:00:00

# %%
df['Check-in Date'] = pd.to_datetime(df['Check-in Date'])
df['Search Date'] = pd.to_datetime(df['Search Date'])

# %%
df['Date_gap'] = df['Check-in Date'] - df['Search Date']
df['Date_gap'] = df['Date_gap'].astype(str)
df["Date_gap"]= df["Date_gap"].replace( r"days","", regex=True)

# Remove $ mark in Rate Column
df['Rate'] = df['Rate'].apply(lambda x: x[3:])
df.head()
# Out:
#                                                Hotel            Room Type  \
# 0  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 1  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 2  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 3  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 4  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
#
#   Rate Check-in Date Search Date Search Time Date_gap
# 0  254    2022-08-03  2022-08-03     0:00:00       0
# 1  254    2022-08-03  2022-08-03     1:00:00       0
# 2  254    2022-08-03  2022-08-03     2:00:00       0
# 3  254    2022-08-03  2022-08-03     3:00:00       0
# 4  254    2022-08-03  2022-08-03     4:00:00       0

# %%
df['check_in_year'] = pd.DatetimeIndex(df['Check-in Date']).year
df['check_in_month'] = pd.DatetimeIndex(df['Check-in Date']).month
df['check_in_date'] = pd.DatetimeIndex(df['Check-in Date']).day

df = df.drop('Check-in Date', axis=1)
df = df.drop('Search Date', axis=1)
df.tail()
# Out:
#                         Hotel                                Room Type Rate  \
# 8046  Tuscany Suites & Casino                          Executive Suite  121
# 8047  Tuscany Suites & Casino                          Executive Suite  139
# 8048  Tuscany Suites & Casino  Deluxe Executive King Non-Smoking Suite  168
# 8049  Tuscany Suites & Casino                          Executive Suite  143
# 8050  Tuscany Suites & Casino                    Executive Double Room  147
#
#      Search Time Date_gap  check_in_year  check_in_month  check_in_date
# 8046    21:00:00      13            2022               8             20
# 8047    22:00:00      13            2022               8             20
# 8048    23:00:00      13            2022               8             20
# 8049     0:00:00      12            2022               8             20
# 8050     0:00:00      12            2022               8             20

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#                                                Hotel            Room Type  \
# 0  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 1  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 2  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 3  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
# 4  2100 SqFt Penthouse Suite W/ Strip Views! POOL...  Penthouse Apartment
#
#   Rate Search Time Date_gap  check_in_year  check_in_month  check_in_date
# 0  254     0:00:00       0            2022               8              3
# 1  254     1:00:00       0            2022               8              3
# 2  254     2:00:00       0            2022               8              3
# 3  254     3:00:00       0            2022               8              3
# 4  254     4:00:00       0            2022               8              3

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
from sklearn.model_selection import train_test_split

# %%
for i in df1.select_dtypes('object').columns:
    encoder = LabelEncoder()
    df1[i] = encoder.fit_transform(df1[i])

# %%
# Check the Correlation with "Rate" column to other columns

# %%
df1.tail()
# Out:
#       Hotel  Room Type  Rate  Search Time  Date_gap  check_in_year  \
# 8046      6         19    20           13         6           2022
# 8047      6         19    33           14         6           2022
# 8048      6          8    57           15         6           2022
# 8049      6         19    37            0         5           2022
# 8050      6         14    41            0         5           2022
#
#       check_in_month  check_in_date
# 8046               8             20
# 8047               8             20
# 8048               8             20
# 8049               8             20
# 8050               8             20

# %%
df1 = df1.astype({"check_in_year":"int","check_in_month":"int"})

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df1.corr(), annot=True)
plt.title('Correlation between the columns')
plt.show()

# %%
df1.corr()['Rate'].sort_values()
# Out:
# Room Type        -0.398470
# Search Time      -0.004465
# Date_gap          0.040234
# check_in_date     0.077944
# Hotel             0.097931
# Rate              1.000000
# check_in_year          NaN
# check_in_month         NaN
# Name: Rate, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051 entries, 0 to 8050
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           8051 non-null   int32
#  1   Room Type       8051 non-null   int32
#  2   Rate            8051 non-null   int32
#  3   Search Time     8051 non-null   int32
#  4   Date_gap        8051 non-null   int32
#  5   check_in_year   8051 non-null   int32
#  6   check_in_month  8051 non-null   int32
#  7   check_in_date   8051 non-null   int64
# dtypes: int32(7), int64(1)
# memory usage: 283.2 KB

# %%
fig = plt.figure(figsize=(7,5))
plt.title('Correlation between Hotel & Rate')
sns.regplot(x='Hotel', y='Rate', data=df1 )
# Out:
# <AxesSubplot:title={'center':'Correlation between Hotel & Rate'}, xlabel='Hotel', ylabel='Rate'>

# %%
x= df1.drop('Rate' , axis=1)
y= df1['Rate']

# %%
print("Shape of x is :", x.shape)
print("Shape of y is :", y.shape)
# Out:
# Shape of x is : (8051, 7)
# Shape of y is : (8051,)

# %%
# Split train test set

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
print('Shape of x_train is: ', x_train.shape)
print('Shape of x_test is: ', x_test.shape)
print('Shape of y_train is: ', y_train.shape)
print('Shape of y_test is: ', y_test.shape)
# Out:
# Shape of x_train is:  (5635, 7)
# Shape of x_test is:  (2416, 7)
# Shape of y_train is:  (5635,)
# Shape of y_test is:  (2416,)

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# ### Linear Regression

# %%
linreg = LinearRegression()
linreg.fit(x_train, y_train)
linreg_pred = linreg.predict(x_test)

# %%
linreg_mae = mean_absolute_error(y_test, linreg_pred)
linreg_r2 = r2_score(y_test, linreg_pred)
print("MAE of Linear Regression model is : ", linreg_mae)
print("R2 Score of Linear Regression model is : ", linreg_r2)
# Out:
# MAE of Linear Regression model is :  38.01941484513516
# R2 Score of Linear Regression model is :  0.1955301692249236

# %%
linreg_score = cross_val_score(linreg, x_test, y_test, cv=4)
print("Linear regression Model Accuuracy is: {}".format(linreg_score.mean()*100))
# Out:
# Linear regression Model Accuuracy is: 18.749780515531217

# %% [markdown]
# ### Decision Tree

# %%
dtree = DecisionTreeRegressor()
dtree.fit(x_train, y_train)
dtree_pred = dtree.predict(x_test)

# %%
dtree_mae = mean_absolute_error(y_test, dtree_pred)
dtree_r2 = r2_score(y_test,dtree_pred)
print("MAE of Decision tree model is : ", dtree_mae)
print("R2 score of Decision tree model is : ", dtree_r2)
# Out:
# MAE of Decision tree model is :  1.4768211920529801
# R2 score of Decision tree model is :  0.9516738872366267

# %%
dtree_score = cross_val_score(dtree, x_test, y_test, cv=4)
print("Decision tree Model Accuuracy is: {}".format(dtree_score.mean()*100))
# Out:
# Decision tree Model Accuuracy is: 90.90170481479738

# %% [markdown]
# ## XGBoost  - Gradient Boost

# %%
xgb = XGBRegressor()
xgb.fit(x_train,y_train)
xgb_pred = xgb.predict(x_test)

# %%
xgb_mae = mean_absolute_error(y_test, dtree_pred)
xgb_r2 = r2_score(y_test,dtree_pred)
print("MAE of xgboost model is : ", xgb_mae)
print("R2 score of xgboost model is : ", xgb_r2)
# Out:
# MAE of xgboost model is :  1.4768211920529801
# R2 score of xgboost model is :  0.9516738872366267

# %%
xgb_score = cross_val_score(xgb, x_test, y_test, cv=4)
print("XGBoost Model Accuuracy is: {}".format(xgb_score.mean()*100))
# Out:
# XGBoost Model Accuuracy is: 91.7921714693309

# %% [markdown]
#   ##      ------------------------------------------------------  Summary  -------------------------
#
#
#  | Algorithm | Model Accuracy | r2 Score |
#  | --- | --- | --- |
#  | Linear Regression | 18.74% | 0.195 |
#  | Decision Tree | 91.28% |  0.947 |
#  | XGBoost - Gradient Boost | 91.79% | 0.947 |

# %%
df1.tail()
# Out:
#       Hotel  Room Type  Rate  Search Time  Date_gap  check_in_year  \
# 8046      6         19    20           13         6           2022
# 8047      6         19    33           14         6           2022
# 8048      6          8    57           15         6           2022
# 8049      6         19    37            0         5           2022
# 8050      6         14    41            0         5           2022
#
#       check_in_month  check_in_date
# 8046               8             20
# 8047               8             20
# 8048               8             20
# 8049               8             20
# 8050               8             20

# %%
data = {'Hotel':1,'Room Type':23,'Search Time':0,'Date_gap':4,'check_in_year':2022,'check_in_month':6,'check_in_date':31}
index = [0]
new_df = pd.DataFrame(data, index)
new_df
# Out:
#    Hotel  Room Type  Search Time  Date_gap  check_in_year  check_in_month  \
# 0      1         23            0         4           2022               6
#
#    check_in_date
# 0             31

# %%
new_pred = xgb.predict(new_df)
print('The Booking price is: ',new_pred)
# Out:
# The Booking price is:  [84.198715]

# %%
new_df['pred_Rate'] = new_pred

# %%
new_df
# Out:
#    Hotel  Room Type  Search Time  Date_gap  check_in_year  check_in_month  \
# 0      1         23            0         4           2022               6
#
#    check_in_date  pred_Rate
# 0             31  84.198715

# %%
new_df1 = df1[['Hotel','Room Type','Rate','Search Time','Date_gap','check_in_year','check_in_month','check_in_date']]
new_df2 = df1[['Hotel','Room Type','Search Time','Date_gap','check_in_year','check_in_month','check_in_date']]

# %%
new_df2.head()
# Out:
#    Hotel  Room Type  Search Time  Date_gap  check_in_year  check_in_month  \
# 0      0         24            0         1           2022               8
# 1      0         24           11         1           2022               8
# 2      0         24           16         1           2022               8
# 3      0         24           17         1           2022               8
# 4      0         24           18         1           2022               8
#
#    check_in_date
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3

# %%
new_df2['pred_Rate'] = xgb.predict(new_df2)
#print('The Booking price is: ',new_pred)
#

# %%
new_df2
# Out:
#       Hotel  Room Type  Search Time  Date_gap  check_in_year  check_in_month  \
# 0         0         24            0         1           2022               8
# 1         0         24           11         1           2022               8
# 2         0         24           16         1           2022               8
# 3         0         24           17         1           2022               8
# 4         0         24           18         1           2022               8
# ...     ...        ...          ...       ...            ...             ...
# 8046      6         19           13         6           2022               8
# 8047      6         19           14         6           2022               8
# 8048      6          8           15         6           2022               8
# 8049      6         19            0         5           2022               8
# 8050      6         14            0         5           2022               8
#
#       check_in_date  pred_Rate
# 0                 3  80.550613
# 1                 3  83.984909
# 2                 3  83.984909
# 3                 3  83.984909
# 4                 3  83.984909
# ...             ...        ...
# 8046             20  75.735405
# 8047             20  75.735405
# 8048             20  75.735405
# 8049             20  75.571526
# 8050             20  75.571526
#
# [8051 rows x 8 columns]

# %%
new_df1
# Out:
#       Hotel  Room Type  Rate  Search Time  Date_gap  check_in_year  \
# 0         0         24    85            0         1           2022
# 1         0         24    85           11         1           2022
# 2         0         24    85           16         1           2022
# 3         0         24    85           17         1           2022
# 4         0         24    85           18         1           2022
# ...     ...        ...   ...          ...       ...            ...
# 8046      6         19    20           13         6           2022
# 8047      6         19    33           14         6           2022
# 8048      6          8    57           15         6           2022
# 8049      6         19    37            0         5           2022
# 8050      6         14    41            0         5           2022
#
#       check_in_month  check_in_date
# 0                  8              3
# 1                  8              3
# 2                  8              3
# 3                  8              3
# 4                  8              3
# ...              ...            ...
# 8046               8             20
# 8047               8             20
# 8048               8             20
# 8049               8             20
# 8050               8             20
#
# [8051 rows x 8 columns]

# %%
new_df2
# Out:
#       Hotel  Room Type  Search Time  Date_gap  check_in_year  check_in_month  \
# 0         0         24            0         1           2022               8
# 1         0         24           11         1           2022               8
# 2         0         24           16         1           2022               8
# 3         0         24           17         1           2022               8
# 4         0         24           18         1           2022               8
# ...     ...        ...          ...       ...            ...             ...
# 8046      6         19           13         6           2022               8
# 8047      6         19           14         6           2022               8
# 8048      6          8           15         6           2022               8
# 8049      6         19            0         5           2022               8
# 8050      6         14            0         5           2022               8
#
#       check_in_date  pred_Rate
# 0                 3  80.550613
# 1                 3  83.984909
# 2                 3  83.984909
# 3                 3  83.984909
# 4                 3  83.984909
# ...             ...        ...
# 8046             20  75.735405
# 8047             20  75.735405
# 8048             20  75.735405
# 8049             20  75.571526
# 8050             20  75.571526
#
# [8051 rows x 8 columns]

# %%
new_df2['Rate'] = new_df1['Rate'].values

# %%
#new_df2 = new_df2.set_index('Booking_ID')

new_df2 = new_df2.reset_index()
new_df2 = new_df2.rename(columns={"index":"Booking_ID_1"})
new_df2['Booking_ID_1'] = df.index+1

# %%
new_df2.head()
# Out:
#    Booking_ID_1 Booking_ID  Hotel  Room Type  Search Time  Date_gap  \
# 0             1    0:00:00      0         24            0         1
# 1             2    1:00:00      0         24           11         1
# 2             3    2:00:00      0         24           16         1
# 3             4    3:00:00      0         24           17         1
# 4             5    4:00:00      0         24           18         1
#
#    check_in_year  check_in_month  check_in_date  pred_Rate  Rate
# 0           2022               8              3  80.550613    85
# 1           2022               8              3  83.984909    85
# 2           2022               8              3  83.984909    85
# 3           2022               8              3  83.984909    85
# 4           2022               8              3  83.984909    85

# %%
new_df2['Booking_ID'] = df['Search Time'].values

# %%
#df = df.drop('Booking_ID')

# %%
new_df2
# Out:
#       Booking_ID_1 Booking_ID  Hotel  Room Type  Search Time  Date_gap  \
# 0                1    0:00:00      0         24            0         1
# 1                2    1:00:00      0         24           11         1
# 2                3    2:00:00      0         24           16         1
# 3                4    3:00:00      0         24           17         1
# 4                5    4:00:00      0         24           18         1
# ...            ...        ...    ...        ...          ...       ...
# 8046          8047   21:00:00      6         19           13         6
# 8047          8048   22:00:00      6         19           14         6
# 8048          8049   23:00:00      6          8           15         6
# 8049          8050    0:00:00      6         19            0         5
# 8050          8051    0:00:00      6         14            0         5
#
#       check_in_year  check_in_month  check_in_date  pred_Rate  Rate
# 0              2022               8              3  80.550613    85
# 1              2022               8              3  83.984909    85
# 2              2022               8              3  83.984909    85
# 3              2022               8              3  83.984909    85
# 4              2022               8              3  83.984909    85
# ...             ...             ...            ...        ...   ...
# 8046           2022               8             20  75.735405    20
# 8047           2022               8             20  75.735405    33
# 8048           2022               8             20  75.735405    57
# 8049           2022               8             20  75.571526    37
# 8050           2022               8             20  75.571526    41
#
# [8051 rows x 11 columns]

# %%
new_df2.plot('Booking_ID',y=['pred_Rate','Rate'])
plt.show()

# %%
new_df2.plot('Booking_ID_1',y=['pred_Rate','Rate'])
plt.show()

# %%
new_df3 = new_df2.head(50)
new_df3.plot('Booking_ID',y=['pred_Rate','Rate'])
plt.show()
